# %%
import cv2
import matplotlib.pyplot as plt
from matplotlib.colors import hsv_to_rgb
import numpy as np

# %%
img_in = cv2.imread('pic.jpg')
hsv = cv2.cvtColor(img_in, cv2.COLOR_BGR2HSV)

print(hsv.shape)

h,s,v = cv2.split(hsv)
#print('s',s.shape)
#v = np.ones(s.shape, dtype='uint8') * 155
#v = np.maximum(0, v)
#print(s)
hsv2 = cv2.merge([h,s,v])

#img = cv2.cvtColor(hsv, cv2.COLOR_HSV2RGB)
#plt.imshow(img)
#plt.show()

img = cv2.cvtColor(hsv2, cv2.COLOR_HSV2RGB)
plt.imshow(img)
plt.show()


for i in range(3):
    pic = hsv2[:,:,i]
    plt.imshow(pic, cmap='gray')
    plt.show()
# Out:
# (1008, 1600, 3)
